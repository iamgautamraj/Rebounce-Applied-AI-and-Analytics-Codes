# %% [markdown]
# <a href="https://colab.research.google.com/github/iamgautamraj/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/Python%20101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("MP1 Starting")
# Out:
# MP1 Starting
